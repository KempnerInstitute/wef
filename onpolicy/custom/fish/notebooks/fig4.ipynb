# %% [markdown]
# # Fig 4 — Sensor Ablations & Interventions
#
# Regenerates all multi-spec outputs that feed `figs/fig4/` via `copy_to_figs.py`.
#
# Panels covered:
# - **fig4/sensor_1fish** — single-fish sensor ablation
# - **fig4/sensor** — multi-fish sensor ablation
# - **fig4/muting** — EOD muting interventions
# - **fig4/collective_sensing** — collective sensing interventions
# - **fig4/food_abundance** — food abundance interventions
# - **fig4/num_patches** — number of patches interventions
# - **fig4/uniform_amp** — uniform ampullary interventions
#
# All groups are run together by `analysis_interventions.run(evals_dir)`.
#
# Derived files for all relevant specs must already exist.

# %%
# RUN_DIR = "/home/satsingh/kr/mfrefactor/onpolicy/custom/fish/results/foraging/20260611_Dyn_F00_Kb_For/20260611_Dyn_F00_Kb_ForSeed1/20260611_202845/" # FULL PATH NEEDED
RUN_DIR = "/srv/marl/satsingh/marl_fish/NEW/foraging/Dyn_F00_Kb_For_S1"

# %%
import sys, os, importlib
sys.path.insert(0, '/home/satsingh/kr/mfrefactor/onpolicy/custom/fish')
os.chdir('/home/satsingh/kr/mfrefactor/onpolicy/custom/fish')
from analysis_style import inline_display

run_dir   = os.path.expanduser(RUN_DIR)
evals_dir = os.path.join(run_dir, 'evals')

# %% [markdown]
# ## All intervention groups
#
# Outputs land in `{run_dir}/multi_eval/interventions/{group}/`.

# %%
import analysis_interventions as m_int; importlib.reload(m_int)
with inline_display():
    m_int.run(evals_dir)
